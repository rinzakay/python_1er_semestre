# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv("Titanic-Dataset.csv")

# %%
conteo = datos["Survived"].value_counts()

# %%
plt.bar(["Fallecidos", "Sobrevivientes"], conteo)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.show()
