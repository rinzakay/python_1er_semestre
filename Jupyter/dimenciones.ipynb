# %%
import numpy as np

# %% [markdown]
# Creando un vector de 12 numeros enteros (desde 1 al 10) random

# %%
vector = np.random.randint(1,11,12)
vector
# Out:
# array([8, 4, 4, 2, 9, 1, 3, 5, 8, 7, 6, 6])

# %% [markdown]
# obstencion de la dimencion de un arreglo

# %%
np.shape(vector)
# Out:
# (12,)

# %% [markdown]
# transformar el vector de 12 elementos en una Matriz 4x3

# %%
matriz = vector.reshape(4,3)
matriz
# Out:
# array([[8, 4, 4],
#        [2, 9, 1],
#        [3, 5, 8],
#        [7, 6, 6]])

# %% [markdown]
# Otra variante de matriz (6x2) generada de la matriz

# %%
matriz_2 = vector.reshape(6,2)
matriz_2
# Out:
# array([[8, 4],
#        [4, 2],
#        [9, 1],
#        [3, 5],
#        [8, 7],
#        [6, 6]])

# %% [markdown]
# Volviendo a consultar la dimención pero de la matriz

# %%
np.shape(matriz)

# %% [markdown]
# **Conociendo la BIBLIOTECA Matplotlib**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# creando un grafico simple

# %%
plt.plot(vector)
plt.title("Grafico de vectores")
plt.xlabel("Indice (posicion)") #Para agregar el eje x al grafico
plt.ylabel("Valor")#Para

plt.grid(True)
# Out:
# Text(0, 0.5, 'Valor')

# %% [markdown]
# **Crear dos vectores en un mismo grafico**

# %%
vector_1 = np.random.randint(1,11,12)
vector_2 = np.random.randint(2,20,12)

# %%
plt.plot(vector_1, marker = 'o', label = vector_1)

plt.title("Comparando dos vectores")
plt.xlabel("Indice (posicion)")
plt.ylabel("Valor")

plt.grid(True)
plt.legend()

plt.show()
# Out:
# /tmp/ipython-input-24-1275904569.py:1: MatplotlibDeprecationWarning: Passing label as a length 12 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(vector_1, marker = 'o', label = vector_1)
# /tmp/ipython-input-24-1275904569.py:2: MatplotlibDeprecationWarning: Passing label as a length 12 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(vector_2, marker = 'o', label = vector_2)

# %% [markdown]
# **Creando un Gráfico de barra**

# %%
plt.bar(range(len(vector_2)))#el metodo bar, permite crear un gráfico de barra
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-2843163088.py in <cell line: 0>()
# ----> 1 plt.bar(range(len(vector_2, vector_1)))#el metodo bar, permite crear un gráfico de barra
#
# NameError: name 'plt' is not defined
